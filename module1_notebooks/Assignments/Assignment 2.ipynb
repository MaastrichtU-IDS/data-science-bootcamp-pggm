# %% [markdown]
# ## Assignment 2

# %%
import pandas as pd

# %%
data = pd.read_csv('http://bit.ly/PGGM_dataset')

# %% [markdown]
# **Define a function that takes the dataset and creates a DataFrame which columns are:
# ‘Variable’, ‘Number of Nulls’, ‘Percentage of Nulls’**

# %%
def missing_values_table(df): 
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum()/len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1).reset_index()
        mis_val_table = mis_val_table.rename(
            columns = {'index':'Variable', 0 : 'Number of Nulls', 1 : 'Percentage of Nulls'})
        return mis_val_table

# %%
missing_values_table(data)
# Out:
#                  Variable  Number of Nulls  Percentage of Nulls
# 0              Identifier                0             0.000000
# 1                    Name                0             0.000000
# 2                  Period                0             0.000000
# 3         Period_YYYYMMDD                0             0.000000
# 4                  Ticker                0             0.000000
# 5    Universe_Returns_F1W                4             0.010443
# 6    Universe_Returns_F4W                8             0.020886
# 7   Universe_Returns_F12W               36             0.093985
# 8                  Weight                0             0.000000
# 9             GICS_Sector                0             0.000000
# 10           GICS_Ind_Grp                0             0.000000
# 11         Market_Cap_USD                0             0.000000
# 12              Price_USD                0             0.000000
# 13                 NTM_EP               58             0.151420
# 14                LTM_ROA               59             0.154031
# 15                     BP               16             0.041771
# 16                 LTM_EP               89             0.232352
# 17        5Y_Sales_Growth              107             0.279344

# %% [markdown]
# **Create a function that replaces all the occurrences of the string “Inc.” for the string
# “B.V.” in any given vector.**

# %%
def find_replace(l, cases):
    for a, b in cases:
        l = [row.replace(a, b) for row in l]
    return l

# %%
cases ={
    ('Inc.','B.V.'),
    ('blue','Blue'),
    ('.',''),
    ('I','Y'),
    ('-','')
    }

# %%
#find_replace(data.Name, cases)

# %% [markdown]
# **Include a new variable in the dataset that corresponds the quarter of the year.**

# %%
data['Quarter'] = pd.PeriodIndex(data.Period, freq='Q-MAR').strftime('Q%q')

# %%
'Year '+str(data.year[0])
# Out:
# 'Year 2014'

# %% [markdown]
# **Create a subset where the columns are the Quarter of the year, and Industry Group
# the Rows, agregating by ROA. Is there any pattern? Export the subset in csv.**

# %%
quarter_group = pd.pivot_table(data, values='LTM_ROA', index='GICS_Ind_Grp', columns='Quarter', 
                               aggfunc='mean',fill_value=0).T

# %%
#quarter_group.T

# %%
quarter_group = quarter_group[quarter_group.mean().sort_values(ascending=False).index]

# %%
quarter_group
# Out:
# GICS_Ind_Grp  Semiconductors & Semiconductor Equipment  Consumer Services  \
# Quarter
# Q1                                           11.589568          12.237632
# Q2                                           12.811544          13.037631
# Q3                                           13.350461          12.741236
# Q4                                           11.570475          11.183710
#
# GICS_Ind_Grp  Transportation  Household & Personal Products  \
# Quarter
# Q1                 11.371819                      10.369939
# Q2                 11.644001                      10.813697
# Q3                 10.800704                      10.599298
# Q4                  9.331235                      10.199596
#
# GICS_Ind_Grp  Food Beverage & Tobacco  Retailing  \
# Quarter
# Q1                           9.985385   9.656272
# Q2                           9.650519  10.234085
# Q3                           9.910466   9.887666
# Q4                           9.495991   9.208273
#
# GICS_Ind_Grp  Commercial & Professional Services  Capital Goods  \
# Quarter
# Q1                                      8.240517       7.035379
# Q2                                      8.870785       7.358007
# Q3                                      8.752008       7.586536
# Q4                                      7.420434       7.159318
#
# GICS_Ind_Grp  Consumer Durables & Apparel  Food & Staples Retailing    ...     \
# Quarter                                                                ...
# Q1                               6.009177                  6.048261    ...
# Q2                               6.264084                  7.050006    ...
# Q3                               6.636719                  6.750695    ...
# Q4                               7.226165                  5.922688    ...
#
# GICS_Ind_Grp  Diversified Financials     Media  Automobiles & Components  \
# Quarter
# Q1                          5.139919  4.755386                  3.756846
# Q2                          5.240579  4.732686                  3.673743
# Q3                          5.229576  4.797754                  3.999376
# Q4                          4.899855  4.657937                  4.110035
#
# GICS_Ind_Grp  Pharmaceuticals Biotechnology & Life Sciences  Real Estate  \
# Quarter
# Q1                                                 1.711677     3.001839
# Q2                                                 4.313217     3.066965
# Q3                                                 5.021505     3.306205
# Q4                                                 1.847954     3.086908
#
# GICS_Ind_Grp  Utilities    Energy  Insurance  Media & Entertainment     Banks
# Quarter
# Q1             2.506484  2.524588   1.956626               0.000000  1.018877
# Q2             2.541458  2.409214   2.048777               0.000000  1.087699
# Q3             2.408358  2.782611   2.310436               6.014303  1.108746
# Q4             2.282353  1.630256   1.806934               0.000000  0.989145
#
# [4 rows x 25 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(18,6))
sns.heatmap(quarter_group, annot=True, annot_kws={"size": 10})

# %% [markdown]
# ** Create a subset where the original dataset is sorted by Market Cap USD and
# determine which month has the highest value in the dataset.**

# %%
data.Period = [pd.to_datetime(i, format='%Y%m%d') for i in data.Period_YYYYMMDD]
data['month'] = [date.month for date in data.Period]
data['day'] = [date.day for date in data.Period]
data['year'] = [date.year for date in data.Period]

# %%
market_sorted = data.sort_values(by='Market_Cap_USD',ascending=False)
market_sorted = market_sorted.groupby(['year','month']).agg(['mean','count','max'])['Market_Cap_USD']

# %%
market_sorted
# Out:
#                     mean  count         max
# year month
# 2014 12     30610.662923    631   660940.75
# 2015 9      28112.869636    637   635441.60
# 2016 8      31952.329342    620   588280.25
#      11     32266.540738    616   605365.00
# 2017 5      34772.696415    624   814564.10
#      12     37684.622108   2532   900557.50
# 2018 1      39457.727861   3160   925092.30
#      2      38283.681472   2528   920030.44
#      3      38234.934084   2524   916166.60
#      4      37676.186519   2524   913086.06
#      5      38309.587983   3155   967099.00
#      6      39193.988141   2511   984257.06
#      7      39673.868663   2505   988519.20
#      8      40611.186460   3130  1131403.40
#      9      41077.593735   2502  1115097.40
#      10     39412.431943   3120  1140656.10
#      11     38757.069367   2493  1031933.25
#      12     36547.138506   2492   853399.60

# %% [markdown]
# ** Which of the overall Industry Group has the lowest 5 years sales growth in average**

# %%
df_ind_grp = data.groupby('GICS_Ind_Grp').mean()['5Y_Sales_Growth'].sort_values().reset_index()

# %%
#df_ind_grp

# %%
plt.figure(figsize=(10,7))
plt.barh(df_ind_grp.GICS_Ind_Grp,df_ind_grp['5Y_Sales_Growth'])
# Out:
# <BarContainer object of 25 artists>

# %% [markdown]
# ** Create a subset of the portfolio which includes all the values where Universe Returns
# indexes higher than the 75 percentile.**

# %%
summary = data.describe().loc['75%', 
                              ['Universe_Returns_F1W','Universe_Returns_F4W','Universe_Returns_F12W']]

# %%
my_summary = data.describe()

# %%
my_summary.loc['75%','5Y_Sales_Growth']
# Out:
# 11.886979

# %%
summary
# Out:
# Universe_Returns_F1W     2.159980
# Universe_Returns_F4W     4.400995
# Universe_Returns_F12W    6.686374
# Name: 75%, dtype: float64

# %%
universe_returns_75perc = data[(data.Universe_Returns_F1W > summary.Universe_Returns_F1W) &
     (data.Universe_Returns_F4W > 4) &
     (data.Universe_Returns_F12W > summary.Universe_Returns_F12W)
    ]

# %%
summary.Universe_Returns_F4W
# Out:
# 4.400995

# %%
universe_returns_75perc.head()
# Out:
#    Identifier                             Name     Period  Period_YYYYMMDD  \
# 12   26441150          Duke Realty Corporation 2014-12-31         20141231
# 20   10113710    Boston Scientific Corporation 2014-12-31         20141231
# 29   22822V10  Crown Castle International Corp 2014-12-31         20141231
# 70   61174X10     Monster Beverage Corporation 2014-12-31         20141231
# 79   25339310      Dick's Sporting Goods, Inc. 2014-12-31         20141231
#
#      Ticker  Universe_Returns_F1W  Universe_Returns_F4W  \
# 12   DRE-US              4.504955             10.396028
# 20   BSX-US              5.886793             10.113203
# 29   CCI-US              2.287173             10.749685
# 70  MNST-US              7.023537             10.023081
# 79   DKS-US             10.795557             10.473310
#
#     Universe_Returns_F12W    Weight             GICS_Sector  ...   Price_USD  \
# 12               8.271610  0.000357              Financials  ...   20.200000
# 20              32.226418  0.000909             Health Care  ...   13.250000
# 29               8.567882  0.001360              Financials  ...   78.700000
# 70              25.542223  0.000797        Consumer Staples  ...   36.116666
# 79              16.739559  0.000248  Consumer Discretionary  ...   49.650000
#
#       NTM_EP    LTM_ROA        BP    LTM_EP  5Y_Sales_Growth  Quarter  month  \
# 12  0.004120   3.146236  0.412802  0.033050        -0.216620       Q3     12
# 20  0.068196   1.712502  0.380982  0.016075        -2.550075       Q3     12
# 29  0.016823   1.204316  0.260514  0.006607        16.179829       Q3     12
# 70  0.029585  25.717973  0.076293  0.023072        16.936647       Q3     12
# 79  0.063510   9.346824  0.285530  0.053575         8.519749       Q3     12
#
#    day  year
# 12  31  2014
# 20  31  2014
# 29  31  2014
# 70  31  2014
# 79  31  2014
#
# [5 rows x 22 columns]

# %% [markdown]
# ** Create a function that can label any given vector in a dicotomic way: above the
# median and below the median.**

# %%
def dicotomic_label(vector):
    """Creates a dicotomic label 
    1: Above the median
    0: Below the median"""
    label = []
    for i in vector:
        if i >= vector.median():
            label.append(1)
        else:
            label.append(0)
    return label

# %%
dicotomic_label?
# Out:
# Signature: dicotomic_label(vector)
# Docstring:
# Creates a dicotomic label
# 1: Above the median
# 0: Below the median
# File:      ~/data-science-bootcamp-pggm/notebooks/<ipython-input-106-5217586d257c>
# Type:      function

# %%
data['Above_median'] = dicotomic_label(data.Weight)

# %%
data['flag_dollars'] = dicotomic_label(data.Price_USD)

# %%
data[data.flag_dollars == 1]
# Out:
#       Identifier                                          Name     Period  \
# 0       17290810                            Cintas Corporation 2014-12-31
# 2       50241310              L-3 Communications Holdings Inc. 2014-12-31
# 38281   81762P10                              ServiceNow, Inc. 2018-12-26
# 38282   98138H10                         Workday, Inc. Class A 2018-12-26
# 38284   70450Y10                           PayPal Holdings Inc 2018-12-26
# 38297   98155810                        Worldpay, Inc. Class A 2018-12-26
# 38300   G5494J10                                     Linde plc 2018-12-26
# 38301   24703L20                 Dell Technologies Inc Class C 2018-12-26
#
#        Period_YYYYMMDD      Ticker  Universe_Returns_F1W  \
# 0             20141231     CTAS-US             -2.517855
# 2             20141231      LLL-US             -0.396162
# 3             20141231      UTX-US             -1.973909
# 7             20141231     ANSS-US             -2.792686
# 9             20141231     EQIX-US             -2.902132
# 10            20141231      LMT-US             -0.903571
# 11            20141231      UHS-US              0.656116
# 13            20141231      WBA-US              0.524938
# 16            20141231      AMG-US             -4.212213
# 17            20141231      VNO-US              4.655516
# 18            20141231      DHR-US             -1.061714
# 21            20141231     ILMN-US              5.601907
# 26            20141231      PRU-US             -5.494142
# 29            20141231      CCI-US              2.287173
# 33            20141231  AGN.XX2-US              0.714993
# 35            20141231      EFX-US              0.593543
# 37            20141231      MAR-US             -2.114576
# 38            20141231      COL-US              0.520825
# 41            20141231      MLM-US             -2.311462
# 42            20141231      UNH-US             -1.147491
# 43            20141231      MCO-US             -1.429909
# 45            20141231      JWN-US              0.037789
# 51            20141231      CPT-US              5.227518
# 52            20141231      ITW-US             -2.787751
# 56            20141231      MKC-US              0.000000
# 57            20141231      ARG-US             -1.423860
# 59            20141231      HON-US             -1.120889
# 60            20141231     PCYC-US              0.989687
# 65            20141231      CLX-US              1.832843
# 71            20141231      CAH-US              1.610303
# ...                ...         ...                   ...
# 38204         20181226      AMP-US              5.121720
# 38205         20181226      FIS-US              2.011466
# 38207         20181226     CHRW-US              0.924349
# 38210         20181226      UAL-US              0.453460
# 38214         20181226      EXR-US             -3.177935
# 38222         20181226      LYB-US              3.033650
# 38227         20181226     SBNY-US             -0.438261
# 38230         20181226     IPGP-US              0.463974
# 38234         20181226      VMW-US              6.482887
# 38237         20181226     JAZZ-US              2.422857
# 38238         20181226      ZTS-US              1.881337
# 38241         20181226       BR-US             -0.450218
# 38243         20181226      CXO-US              4.016769
# 38249         20181226        V-US              2.065575
# 38254         20181226       CB-US              1.807570
# 38255         20181226     VEEV-US              0.644195
# 38263         20181226      MSI-US              2.326822
# 38265         20181226      HII-US              4.788852
# 38267         20181226     SPLK-US              3.558183
# 38268         20181226        W-US              0.734890
# 38269         20181226       FB-US              1.117897
# 38274         20181226     EXPE-US             -1.943952
# 38276         20181226     FANG-US              3.511250
# 38278         20181226      PSX-US              4.655588
# 38281         20181226      NOW-US              5.197346
# 38282         20181226     WDAY-US              3.855407
# 38284         20181226     PYPL-US              3.562796
# 38297         20181226       WP-US              0.932705
# 38300         20181226      LIN-US              2.919984
# 38301         20181226     DELL-US              4.879093
#
#        Universe_Returns_F4W  Universe_Returns_F12W    Weight  \
# 0                 -0.121111               4.156041  0.000402
# 2                 -1.283580              -0.753021  0.000563
# 3                  1.669562               1.815629  0.005174
# 7                 -0.493902               5.390239  0.000391
# 9                 -4.247337               1.677120  0.000624
# 33                Health Care      ...       11.936449  0.111779  0.020199
# 35                Industrials      ...        7.608684  0.241718  0.034490
# 37     Consumer Discretionary      ...       10.610040 -0.084338  0.030117
# 38                Industrials      ...        9.853165  0.168310  0.052320
# 41                  Materials      ...        2.387588  0.589084  0.021521
# 42                Health Care      ...        6.618487  0.338076  0.055000
# 43                 Financials      ...       20.968059  0.012804  0.046133
# 45     Consumer Discretionary      ...        8.211045  0.150675  0.047540
# 51                 Financials      ...        2.606284  0.419531  0.022672
# 52                Industrials      ...        9.469043  0.214979  0.074340
# 56           Consumer Staples      ...        9.516039  0.204662  0.042799
# 57                  Materials      ...        6.214085  0.231719  0.041240
# 59                Industrials      ...        9.339088  0.242293  0.053243
# 60                Health Care      ...       11.174875  0.077686  0.008915
# 65           Consumer Staples      ...       13.489528  0.012383  0.037334
# 71                Health Care      ...        4.401640  0.234827  0.039267
# ...                       ...      ...             ...       ...       ...
# 38204              Financials      ...        1.197205  0.309675  0.089557
# 38205  Information Technology      ...        6.401600  0.284713  0.042427
# 38207             Industrials      ...       14.533652  0.122952  0.048467
# 38210             Industrials      ...        5.141759  0.359392  0.083247
# 38214             Real Estate      ...        7.105369  0.197310  0.043443
# 38222               Materials      ...       21.850609  0.305695  0.160433
# 38227              Financials      ...        1.053627  0.620447  0.068191
# 38230  Information Technology      ...       15.865682  0.290618  0.048822
# 38234  Information Technology      ...        6.795849  0.159092  0.021309
# 38237             Health Care      ...        9.915962  0.331920  0.055923
# 38238             Health Care      ...       11.789133  0.046911  0.025354
# 38241  Information Technology      ...       13.768884  0.099793  0.035683
# 38243                  Energy      ...        5.329267  0.660247  0.055484
# 38249  Information Technology      ...       14.489585  0.090899  0.030122
# 38254              Financials      ...        3.066259  0.825944  0.082025
# 38255             Health Care      ...       15.746858  0.081600  0.012902
# 38263  Information Technology      ...       -0.352653 -0.065752 -0.002964
# 38265             Industrials      ...       11.122787  0.196946  0.072297
# 38267  Information Technology      ...      -10.236678  0.086112 -0.018800
# 38268  Consumer Discretionary      ...      -35.524646 -0.032620 -0.045836
# 38269  Communication Services      ...       22.742491  0.198880  0.047189
# 38274  Consumer Discretionary      ...        2.326888  0.243338  0.023906
# 38276                  Energy      ...        7.646725  0.544765  0.059968
# 38278                  Energy      ...       12.057534  0.540737  0.142707
# 38281  Information Technology      ...       -1.850140  0.030710 -0.001923
# 38282  Information Technology      ...       -8.426479  0.051274 -0.011429
# 38284  Information Technology      ...        5.137142  0.149529  0.020044
# 38297  Information Technology      ...       -0.887806  0.403495 -0.008520
# 38300               Materials      ...        7.117014  0.136119  0.031020
# 38301  Information Technology      ...       -2.104868  0.093597 -0.031492
#
#        5Y_Sales_Growth  Quarter  month  day  year Above_median  flag_dollars
# 0             4.718765       Q3     12   31  2014            0             1
# 2            -4.316938       Q3     12   31  2014            0             1
# 3             3.083364       Q3     12   31  2014            1             1
# 7            12.523060       Q3     12   31  2014            0             1
# 9            23.247128       Q3     12   31  2014            0             1
# 10            0.396690       Q3     12   31  2014            1             1
# 11            7.782109       Q3     12   31  2014            0             1
# 13            3.630590       Q3     12   31  2014            1             1
# 16           18.739765       Q3     12   31  2014            0             1
# 17           -0.413458       Q3     12   31  2014            1             1
# 18           10.066932       Q3     12   31  2014            1             1
# 21           19.763933       Q3     12   31  2014            1             1
# 26           12.850090       Q3     12   31  2014            1             1
# 29           16.179829       Q3     12   31  2014            1             1
# 33            7.849443       Q3     12   31  2014            1             1
# 35            5.030728       Q3     12   31  2014            0             1
# 37            1.712689       Q3     12   31  2014            1             1
# 38            2.471968       Q3     12   31  2014            0             1
# 41            3.799257       Q3     12   31  2014            0             1
# 42            8.894438       Q3     12   31  2014            1             1
# 43           11.942828       Q3     12   31  2014            1             1
# 45            8.022045       Q3     12   31  2014            0             1
# 51            6.234367       Q3     12   31  2014            0             1
# 52           -3.147788       Q3     12   31  2014            1             1
# 56            5.655386       Q3     12   31  2014            0             1
# 57            4.132504       Q3     12   31  2014            0             1
# 59            2.986491       Q3     12   31  2014            1             1
# 60         1235.987500       Q3     12   31  2014            0             1
# 65            0.721761       Q3     12   31  2014            1             1
# 71           -2.947465       Q3     12   31  2014            1             1
# ...                ...      ...    ...  ...   ...          ...           ...
# 38204         2.093063       Q3     12   26  2018            1             1
# 38205        11.118547       Q3     12   26  2018            1             1
# 38207         5.678398       Q3     12   26  2018            0             1
# 38210         0.247723       Q3     12   26  2018            0             1
# 38214        21.037575       Q3     12   26  2018            0             1
# 38222        -2.343704       Q3     12   26  2018            1             1
# 38227        16.316908       Q3     12   26  2018            0             1
# 38230        22.641706       Q3     12   26  2018            0             1
# 38234        11.061884       Q3     12   26  2018            0             1
# 38237        19.212190       Q3     12   26  2018            0             1
# 38238         4.465006       Q3     12   26  2018            1             1
# 38241        14.785678       Q3     12   26  2018            0             1
# 38243        14.530378       Q3     12   26  2018            1             1
# 38249        13.069693       Q3     12   26  2018            1             1
# 38254        16.716936       Q3     12   26  2018            1             1
# 38255        36.465550       Q3     12   26  2018            0             1
# 38263        -2.417072       Q3     12   26  2018            1             1
# 38265         2.414406       Q3     12   26  2018            0             1
# 38267        43.067850       Q3     12   26  2018            1             1
# 38268        50.278336       Q3     12   26  2018            0             1
# 38269        50.791540       Q3     12   26  2018            1             1
# 38274        20.265293       Q3     12   26  2018            0             1
# 38276        83.356890       Q3     12   26  2018            1             1
# 38278        -5.940954       Q3     12   26  2018            1             1
# 38281        48.023090       Q3     12   26  2018            1             1
# 38282        47.285164       Q3     12   26  2018            1             1
# 38284        18.677155       Q3     12   26  2018            1             1
# 38297        16.212727       Q3     12   26  2018            1             1
# 38300         0.898848       Q3     12   26  2018            1             1
# 38301        16.895409       Q3     12   26  2018            1             1
#
# [19155 rows x 24 columns]

# %% [markdown]
# ** Create an excel file which contains 3 different sheets respectively for 2016, 2017,2018. Each including the same combination of the portfolio. The portfolio should be
# equally represented by all sectors. **

# %%
excelbook = pd.ExcelWriter('portfolio.xlsx')

# %%
.to_excel(excelbook, 'sheet1')
.to_excel(excelbook, 'sheet2')
.to_excel(excelbook, 'sheet2')
excelbook.save()

# %% [markdown]
# ** Create a story in a notebook that reports the Data Exploration of the dataset **
